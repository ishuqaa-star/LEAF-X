# %%
import ollama

# %%
response = ollama.chat(
    model="mistral",
    messages=[
        {"role": "user",
          "content": "What is the capital of india?"}
    ]
)
print(response['message']['content'])
# Out:
#  The capital of India is New Delhi. It serves as the center of government, politics and administration. However, it's important to note that New Delhi is not an administrative division of India; instead, it is a union territory and acts as the seat of the federal government. The largest city by population within the country is Mumbai in Maharashtra state.

# %%
import streamlit as st

st.title("Your Personal Gym Assistant")

question = st.text_input("Ask Question regarding Gym...")

def gym_trainer(question):
    response = ollama.chat(
        model = 'mistral',
        messages=[
            {
                'role' : 'system',
                'content' : """ You are a gym trainer. 
                rules:
                    - Be polite and friendly
                    - keep answers short and to the point
                    - give diet plan for weight loss
                """
            },
            {
                'role' : 'user',
                'content' : question
            }
        ]
    )
    return response['message']['content']

if st.button("Send"):
    st.write(gym_trainer(question))
# Out:
# 2026-06-14 19:31:32.658 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-14 19:31:32.660 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-14 19:31:32.663 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-14 19:31:32.665 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-14 19:31:32.666 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-14 19:31:32.667 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-14 19:31:32.668 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-14 19:31:32.669 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-14 19:31:32.671 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-14 19:31:32.672 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-14 19:31:32.672 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-14 19:31:32.673 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-14 19:31:32.673 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-14 19:31:32.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-14 19:31:32.675 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-14 19:31:32.676 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
import ollama
import streamlit as st

st.title("Your Personal Gym Assistant")

question = st.text_input("Ask Question regarding Gym...")

def gym_trainer(question):
    response = ollama.chat(
        model = 'mistral',
        messages=[
            {
                'role' : 'system',
                'content' : """ You are a gym trainer. 
                rules:
                    - Be polite and friendly
                    - keep answers short and to the point
                    - give diet plan for weight loss
                """
            },
            {
                'role' : 'user',
                'content' : question
            }
        ]
    )
    return response['message']['content']

if st.button("Send"):
    st.write(gym_trainer(question))
# Out:
# 2026-06-14 19:30:25.452 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-14 19:30:25.453 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-14 19:30:25.454 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-14 19:30:25.456 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-14 19:30:25.458 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-14 19:30:25.459 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-14 19:30:25.459 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-14 19:30:25.460 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-14 19:30:25.461 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-14 19:30:25.461 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-14 19:30:25.463 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-14 19:30:25.465 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-14 19:30:25.466 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-14 19:30:25.467 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-14 19:30:25.468 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-14 19:30:25.470 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
